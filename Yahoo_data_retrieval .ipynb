# %% [markdown]
# ### Retrieving data from Yahoo!Finance

# %% [markdown]
# 1. Go to http://finance.yahoo.com/.
# 2. Enter IBM in the search box.
# 3. Click on Historical Price in the middle.
# 4. Choose the monthly data, then click Apply.
# 5. Click Download data under Apply.

# %%
#usual imports 

import pandas as pd

# %%
df = pd.read_csv("IBM.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-02-01  144.250000  158.750000  126.360001  130.149994  123.664551
# 1  2020-03-01  130.750000  136.100006   90.559998  110.930000  106.502930
# 2  2020-04-01  106.360001  129.309998  104.519997  125.559998  120.549057
# 3  2020-05-01  123.190002  126.970001  111.809998  124.900002  119.915405
# 4  2020-06-01  124.639999  135.880005  115.879997  120.769997  117.505257
#
#       Volume
# 0  118150200
# 1  190076300
# 2  130697400
# 3   92885900
# 4  120996800

# %%
df.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 8   2020-10-01  122.360001  135.500000  105.919998  111.660004  110.064018
# 9   2020-11-01  112.650002  125.309998  111.160004  123.519997  121.754494
# 10  2020-12-01  123.900002  127.690002  121.720001  125.879997  125.879997
# 11  2021-01-01  125.849998  131.880005  123.040001  129.210007  129.210007
# 12  2021-01-13  129.149994  129.750000  128.110001  128.125000  128.125000
#
#        Volume
# 8   159117500
# 9   103669300
# 10  102829600
# 11   37784300
# 12     582903

# %% [markdown]
# ### Alternative in getting IBM data

# %%
pip install pandas-datareader
# Out:
# ...
#      |████████████████████████████████| 107 kB 4.7 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall pandas-datareader
# Out:
# Found existing installation: pandas-datareader 0.9.0
# Uninstalling pandas-datareader-0.9.0:
#   Would remove:
#     /Users/dark_prince/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader-0.9.0.dist-info/*
#     /Users/dark_prince/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/*
# Proceed (y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
import pandas_datareader.data as getData

df1 = getData.get_data_yahoo("IBM")

# %%
df1.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-01-07  130.460007  128.259995  130.039993  128.990005  4507400.0
# 2021-01-08  129.320007  126.980003  128.570007  128.529999  4676200.0
# 2021-01-11  129.679993  127.660004  127.949997  128.580002  5602500.0
# 2021-01-12  129.850006  127.940002  129.089996  129.210007  3747700.0
# 2021-01-13  129.750000  127.519997  129.149994  127.820000  1303452.0
#
#              Adj Close
# Date
# 2021-01-07  128.990005
# 2021-01-08  128.529999
# 2021-01-11  128.580002
# 2021-01-12  129.210007
# 2021-01-13  127.820000

# %%
df.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 8   2020-10-01  122.360001  135.500000  105.919998  111.660004  110.064018
# 9   2020-11-01  112.650002  125.309998  111.160004  123.519997  121.754494
# 10  2020-12-01  123.900002  127.690002  121.720001  125.879997  125.879997
# 11  2021-01-01  125.849998  131.880005  123.040001  129.210007  129.210007
# 12  2021-01-13  129.149994  129.750000  128.110001  128.125000  128.125000
#
#        Volume
# 8   159117500
# 9   103669300
# 10  102829600
# 11   37784300
# 12     582903

# %% [markdown]
# We can see there are some differences in the data using the two methods

# %% [markdown]
# ### Getting a longer time period using datetime

# %%
import pandas_datareader.data as getData
import datetime

# %%
begdate = datetime.datetime(2000,11,1)
enddate= datetime.datetime(2021,10,1)

# %%
df2 = getData.get_data_yahoo("IBM",begdate, enddate)

# %%
df2.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2000-11-01   99.8750   97.2500   98.4375   98.5625  7466200.0  62.973667
# 2000-11-02  102.3125   98.5000   99.0000  101.9375  7445100.0  65.130013
# 2000-11-03  102.6250   99.3750  102.5000  100.1250  5848500.0  63.971943
# 2000-11-06  102.3750   99.4375   99.8750  100.3125  4448500.0  64.091782
# 2000-11-07  103.5000  100.6875  101.1250  102.3125  5420600.0  65.369598

# %% [markdown]
# A careful reader should find that the order of data is different. When downloading data manually, the order is from the latest (such as yesterday) going back in history. However, when retrieving data via a function, we would have the oldest date first. Most financial databases adopt the same sorting order: from the oldest to the latest.

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install finplot
# Out:
# ...
#      |████████████████████████████████| 46 kB 6.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 47.6 MB 55.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 824 kB 36.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 6.5 MB/s  eta 0:00:01
# ...
# ERROR: spyder 4.0.1 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 4.0.1 has requirement pyqt5<5.13; python_version >= "3", but you'll have pyqt5 5.15.2 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import finplot as fplt

df = yf.download('SPY',start='2018-01-01', end = '2020-04-29')
fplt.candlestick_ochl(df[['Open','Close','High','Low']])
fplt.plot(df.Close.rolling(50).mean())
fplt.plot(df.Close.rolling(200).mean())
fplt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
pip install --upgrade mplfinance
# Out:
# ...
#      |████████████████████████████████| 55 kB 6.6 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, WeekdayLocator
from matplotlib.dates import HourLocator,DayLocator, MONDAY
from matplotlib.finance import candlestick_ohlc,plot_day_summary_oclh
from matplotlib.finance import quotes_historical_yahoo_ochl as getData
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-bdb14180e116> in <module>
#       3 from matplotlib.dates import DateFormatter, WeekdayLocator
#       4 from matplotlib.dates import HourLocator,DayLocator, MONDAY
# ----> 5 from matplotlib.finance import candlestick_ohlc,plot_day_summary_oclh
#       6 from matplotlib.finance import quotes_historical_yahoo_ochl as getData
#
# ModuleNotFoundError: No module named 'matplotlib.finance'
